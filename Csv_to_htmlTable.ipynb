# %%
import pandas as pd

path = "Resources/City_Data_df.csv"
City_Data_df = pd.read_csv(path)

City_Data_df.head()
# Out:
#       Cities Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kieta      PG  -6.2167  155.6333     26.51        84          68
# 1    Mataura      NZ -46.1927  168.8643      8.60        97         100
# 2   Ayacucho      PE -13.1583  -74.2239     12.92        62          75
# 3  Les Cayes      HT  18.2000  -73.7500     27.83        65          44
# 4    Yunyang      CN  33.4474  112.7142     19.09        73         100
#
#    WindSpeed        Date
# 0       2.79  1621341586
# 1       3.81  1621341587
# 2       0.60  1621341347
# 3       3.84  1621341587
# 4       2.65  1621341587

# %%
print(City_Data_df.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Cities</th>
#       <th>Country</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>WindSpeed</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Kieta</td>
#       <td>PG</td>
#       <td>-6.2167</td>
#       <td>155.6333</td>
#       <td>26.51</td>
#       <td>84</td>
#       <td>68</td>
#       <td>2.79</td>
#       <td>1621341586</td>
#     </tr>
#     <tr>
#       <td>Mataura</td>
#       <td>NZ</td>
#       <td>-46.1927</td>
#       <td>168.8643</td>
#       <td>8.60</td>
#       <td>97</td>
#       <td>100</td>
#       <td>3.81</td>
#       <td>1621341587</td>
#     </tr>
#     <tr>
#       <td>Ayacucho</td>
#       <td>PE</td>
#       <td>-13.1583</td>
#       <td>-74.2239</td>
#       <td>12.92</td>
#       <td>62</td>
#       <td>75</td>
# ...
